# %%
import numpy as np
import random as rnd
import pandas as pd
import sys, os, glob

# %%
for p in range(30):
    s1 = np.array([[rnd.randint(1,3) if rnd.randint(0,1)==1 else 0 for i in range(int(100000/300)) ] for j in range(4)])
    np.save("s{}.npy".format(p+1),s1)

# %%
s11
# Out:
# [1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  1,
#  1,
#  1,
#  3,
#  1,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  2,
#  3,
#  1,
#  2,
#  2,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  1,
#  2,
#  3,
#  3,
#  1,
#  2,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  2,
#  3,
#  3,
#  1,
#  2,
#  1,
#  3,
#  3,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  2,
#  1,
#  3,
#  2,
#  1,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  3,
#  3,
#  2,
#  1,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  2,
#  3,
#  3,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  2,
#  2,
#  3,
#  3,
#  1,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2]
